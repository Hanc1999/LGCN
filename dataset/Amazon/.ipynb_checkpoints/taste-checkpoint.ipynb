# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
with open('./train_data.json', 'r') as f:
    data_train = json.load(f)
with open('./test_data.json', 'r') as f:
    data_test = json.load(f)
with open('./validation_data.json', 'r') as f:
    data_valid = json.load(f)

# %%
trans_ctr = 0
tidx_set = set()
for trans in data_train:
    tidx_set.update(trans)
    trans_ctr += len(trans)

# %%
len(tidx_set), max(tidx_set), len(data_train), trans_ctr
# Out:
# (11589, 11588, 20247, 279421)

# %% [markdown]
# ![image.png](attachment:bf3e1c2f-cf86-4c2f-b0ff-6dc156e29635.png)

# %%
len(data_train), len(data_test), len(data_valid)
# Out:
# (20247, 20247, 20247)

# %%
with open('../MBA/tri_graph_uidx2pidx.json', 'r') as f:
    tri_graph_uidx2pidx = json.load(f)
with open('../MBA/tri_graph_tidx2pidx.json', 'r') as f:
    tri_graph_tidx2pidx = json.load(f)
with open('../MBA/tri_graph_uidx2tidx_train.json', 'r') as f:
    tri_graph_uidx2tidx_train = json.load(f)

# %%
tri_graph_uidx2tidx_train['3975'][0]+1
# Out:
# 53
